# %%
import pandas as pd

filtered_df = pd.read_excel("C:/Users/anush/Desktop/Torikumi_New.xlsx")

# %%
logical = (pd.notnull(filtered_df['Rikishi1_Height'])) & (pd.notnull(filtered_df['Rikishi1_Weight'])) & \
        (pd.notnull(filtered_df['Rikishi2_Height'])) & (pd.notnull(filtered_df['Rikishi2_Weight'])) & \
        (pd.notnull(filtered_df['Rikishi1_Age'])) & (pd.notnull(filtered_df['Rikishi2_Age'])) & \
        (pd.notnull(filtered_df['Rikishi1_Hometown'])) & (pd.notnull(filtered_df['Rikishi2_Hometown'])) & \
        (pd.notnull(filtered_df['Rikishi1_modified_rank'])) & (pd.notnull(filtered_df['Rikishi2_modified_rank'])) & \
        (pd.notnull(filtered_df['Rikishi1_Stable'])) & (pd.notnull(filtered_df['Rikishi2_Stable'])) & \
        (pd.notnull(filtered_df['Rikishi1_wins'])) & (pd.notnull(filtered_df['Rikishi1_losses'])) & (pd.notnull(filtered_df['Rikishi1_draws'])) & \
        (pd.notnull(filtered_df['Rikishi2_wins'])) & (pd.notnull(filtered_df['Rikishi2_losses'])) & (pd.notnull(filtered_df['Rikishi2_draws'])) & \
        (pd.notnull(filtered_df['Rikishi1_career_wins'])) & (pd.notnull(filtered_df['Rikishi1_career_losses'])) & \
        (pd.notnull(filtered_df['Rikishi2_career_wins'])) & (pd.notnull(filtered_df['Rikishi2_career_losses'])) & \
        (pd.notnull(filtered_df['Rikishi1_Winning_Kimarite_count'])) & (pd.notnull(filtered_df['Rikishi1_Losing_Kimarite_count'])) & \
        (pd.notnull(filtered_df['Rikishi2_Winning_Kimarite_count'])) & (pd.notnull(filtered_df['Rikishi2_Losing_Kimarite_count'])) & \
        (pd.notnull(filtered_df['Kimarite']))

filtered_df = filtered_df[logical]

filtered_df[['Rikishi1_Height', 'Rikishi1_Weight', 'Rikishi2_Height', 'Rikishi2_Weight']] = filtered_df[['Rikishi1_Height', 'Rikishi1_Weight', 'Rikishi2_Height', 'Rikishi2_Weight']].astype('float64')

# %%
filtered_df['height_diff'] = filtered_df['Rikishi1_Height'] - filtered_df['Rikishi2_Height']  # diff in height (cm)
filtered_df['weight_diff'] = filtered_df['Rikishi1_Weight'] - filtered_df['Rikishi2_Weight']  # diff in weight (kg)
filtered_df['age_diff'] = filtered_df['Rikishi1_Age'] - filtered_df['Rikishi2_Age']  # diff in weight (kg)
filtered_df['rank_diff'] = filtered_df['Rikishi1_modified_rank'] - filtered_df['Rikishi2_modified_rank']  # diff in weight (kg)

# %%
import category_encoders as ce

encoder_value = ce.OrdinalEncoder(cols=['Rikishi1_Stable', 'Rikishi2_Stable', 'Kimarite'], handle_missing='return_nan', return_df= True)
filtered_df=encoder_value.fit_transform(filtered_df)
filtered_df
# Out:
# C:\Users\anush\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#        Unnamed: 0    Basho Day  Rikishi1_id Rikishi1_rank  \
# 0               0  2001.01   1           45           J3e
# 1               1  2001.01   1           33          M11e
# 2               2  2001.01   1           34          M11w
# 3               3  2001.01   1           41           J1e
# 4               4  2001.01   1           42           J1w
# ...           ...      ...  ..          ...           ...
# 59909       59909  2021.03  15         2600           J7e
# 59914       59914  2021.03  15         1953           J7w
# 59915       59915  2021.03  15         2124          M13e
# 59920       59920  2021.03  15          126          M10e
# 59921       59921  2021.03  15         2841           M2w
#
# ...

# %%
import numpy as np
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

# create dataset
#X_scaled, y = make_classification(n_samples=59817, n_features=24, random_state=1, n_informative=2, n_redundant=22)
# configure the cross-validation procedure

X = filtered_df.loc[:, ['height_diff', 'weight_diff', 'age_diff', 'rank_diff', 'Rikishi1_Hometown', 'Rikishi2_Hometown', 'Rikishi1_Stable', 'Rikishi2_Stable', 'Rikishi1_wins', 'Rikishi1_losses', 'Rikishi1_draws', 'Rikishi2_wins', 'Rikishi2_losses', 'Rikishi2_draws', 'Rikishi1_career_wins', 'Rikishi1_career_losses', 'Rikishi2_career_wins', 'Rikishi2_career_losses', 'Rikishi1_Winning_Kimarite_count', 'Rikishi1_Losing_Kimarite_count', 'Rikishi2_Winning_Kimarite_count', 'Rikishi2_Losing_Kimarite_count', 'Kimarite']]
scaler = StandardScaler(copy=True, with_mean=False, with_std=True)
X_scaled = scaler.fit_transform(X)
y = filtered_df.loc[:, 'Label']  # labels, outcomes for first sumo (1 for wins, 0 for losses)

# define the model
clf1 = LogisticRegression(multi_class='multinomial',solver='newton-cg',random_state=1)
clf2 = KNeighborsClassifier(algorithm='ball_tree',leaf_size=20)
clf3 = DecisionTreeClassifier(random_state=1)
clf4 = GaussianNB()  
clf5 = SVC()
    
# define search space
param_grid1 = [{'penalty': ['l2'],'C': np.power(10., np.arange(-4, 4))}]
param_grid2 = [{'n_neighbors': list(range(1, 10)),'p': [1, 2]}]
param_grid3 = [{'max_depth': list(range(1, 10)) + [None],'criterion': ['gini', 'entropy']}]
param_grid4 = [{'var_smoothing': np.logspace(0,-9, num=100)}]
param_grid5 = [{'kernel': ['linear'],'C': [1,10]}]

cv_inner = KFold(n_splits=5, shuffle=True, random_state=1)
# define search    
gridcvs = {}
for pgrid, est, name in zip((param_grid1, param_grid2, param_grid3, param_grid4, param_grid5),(clf1, clf2, clf3, clf4, clf5),('LR', 'KNN', 'DTree', 'GNB', 'SVM')):
    search = GridSearchCV(estimator=est,param_grid=pgrid,scoring='accuracy',n_jobs=-1,cv=cv_inner,verbose=0,refit=True)
    gridcvs[name] = search
        
cv_outer = KFold(n_splits=10, shuffle=True, random_state=1)
# enumerate splits
outer_results = list()
        
for name, gs_est in sorted(gridcvs.items()):
    print(50 * '-', '\n')
    print('Algorithm:', name)
    print('    Inner loop:')
    for train_ix, test_ix in cv_outer.split(X_scaled):
        # split data
        X_train, X_test = X_scaled[train_ix, :], X_scaled[test_ix, :]
        y_train, y_test = y.iloc[train_ix], y.iloc[test_ix]
        result = gridcvs[name].fit(X_train, y_train) # run inner loop hyperparam tuning
        
        # get the best performing model fit on the whole training set
        best_model = result.best_estimator_
        # evaluate model on the hold out dataset
        yhat = best_model.predict(X_test)
        # evaluate the model
        acc = accuracy_score(y_test, yhat)
        # store the result
        outer_results.append(acc)
        # report progress
        print('>acc=%.3f, est=%.3f, cfg=%s' % (acc, result.best_score_, result.best_params_))     
    # summarize the estimated performance of the model
    print('\n    Outer Loop:')
    print('ACC : %.3f (%.3f)' % (mean(outer_results), std(outer_results)))
# Out:
# --------------------------------------------------
#
# Algorithm: DTree
#     Inner loop:
# >acc=0.975, est=0.974, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.978, est=0.972, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.980, est=0.971, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.974, est=0.974, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.982, est=0.973, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.976, est=0.972, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.980, est=0.970, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.970, est=0.972, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.975, est=0.970, cfg={'criterion': 'entropy', 'max_depth': None}
# >acc=0.979, est=0.977, cfg={'criterion': 'entropy', 'max_depth': None}
#
#     Outer Loop:
# ACC : 0.977 (0.003)
# --------------------------------------------------
#
# Algorithm: GNB
#     Inner loop:
# ...
